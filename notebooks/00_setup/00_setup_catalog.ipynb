# %%
# %sql
-- Catalog and schema for this project
CREATE CATALOG IF NOT EXISTS retailpulse;
CREATE SCHEMA IF NOT EXISTS retailpulse.lakehouse;

-- Volume for the simulated "live feed" landing zone
CREATE VOLUME IF NOT EXISTS retailpulse.lakehouse.landing_zone;

-- Volume for Autoloader's schema inference + checkpoint metadata (Part 2)
CREATE VOLUME IF NOT EXISTS retailpulse.lakehouse.checkpoints;

# %%
# %sql
SHOW VOLUMES IN retailpulse.lakehouse;
